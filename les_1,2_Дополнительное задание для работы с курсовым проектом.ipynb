# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/train.csv')
df_train
# Out:
#          Id  DistrictId  Rooms  ...  Shops_1  Shops_2          Price
# 0     11809          27    3.0  ...        0        B  305018.871089
# 1      3013          22    1.0  ...        0        B  177734.553407
# 2      8215           1    3.0  ...        1        B  282078.720850
# 3      2352           1    1.0  ...        1        B  168106.007630
# 4     13866          94    2.0  ...        6        B  343995.102962
# ...     ...         ...    ...  ...      ...      ...            ...
# 9995   1260          61    2.0  ...        9        B  119367.455796
# 9996  16265          27    2.0  ...        0        A  199715.148807
# 9997   2795         178    1.0  ...        5        B  165953.912580
# 9998  14561          21    1.0  ...        5        B  171842.411855
# 9999   7202          94    1.0  ...        9        B  177685.627486
#
# [10000 rows x 20 columns]

# %%
sign_lst = []
min_lst = []
max_lst = []
mean_lst = []

for i in df_train:
  if i == "Id":
    continue
  sign_lst.append(i)
  is_int = df_train[i]
  try:
    min_lst.append(df_train[i].min())
    max_lst.append(df_train[i].max())
    mean_lst.append(df_train[i].mean())
  except TypeError:
    mean_lst.append(0)

df_train_min_max_mean = {
    "sign": sign_lst,
    "min": min_lst,
    "max": max_lst,
    "mean": mean_lst,
}

feature_statistics = pd.DataFrame(df_train_min_max_mean)
feature_statistics
# Out:
#              sign       min       max           mean
# 0      DistrictId         0       209      50.400800
# 1           Rooms         0        19       1.890500
# 2          Square   1.13686   641.065      56.315775
# 3      LifeSquare  0.370619   7480.59      37.199645
# 4   KitchenSquare         0      2014       6.273300
# 5           Floor         1        42       8.526700
# 6      HouseFloor         0       117      12.609400
# 7       HouseYear      1910  20052011    3990.166300
# 8       Ecology_1         0  0.521867       0.118858
# 9       Ecology_2         A         B       0.000000
# 10      Ecology_3         A         B       0.000000
# 11       Social_1         0        74      24.687000
# 12       Social_2       168     19083    5352.157400
# 13       Social_3         0       141       8.039200
# 14   Healthcare_1         0      4849    1142.904460
# 15    Helthcare_2         0         6       1.319500
# 16        Shops_1         0        23       4.231300
# ...

# %%
len(df_train["Rooms"].unique())
# Out:
# 9

# %%
df_train["Rooms"].unique()
# Out:
# array([ 3.,  1.,  2.,  4.,  5., 10.,  0., 19.,  6.])

# %%
df_train["Rooms"].value_counts()
# Out:
# 2.0     3880
# 1.0     3705
# 3.0     2235
# 4.0      150
# 5.0       18
# 0.0        8
# 10.0       2
# 19.0       1
# 6.0        1
# Name: Rooms, dtype: int64

# %%
sign_lst = 
my_unique = []

for i in df_train:
  if i == "Id" or i == "Price":
    continue
  my_unique.append(df_train[i].value_counts())

df_train_unique = {
    "sign": sign_lst,
    ""
}

my_unique
# Out:
# [{0: 48,
#   1: 652,
#   2: 78,
#   3: 82,
#   4: 11,
#   5: 34,
#   6: 511,
#   7: 92,
#   8: 142,
#   9: 294,
#   10: 56,
#   11: 129,
#   12: 64,
#   13: 97,
#   14: 17,
#   15: 36,
#   16: 6,
#   17: 59,
#   18: 51,
#   19: 31,
#   20: 24,
#   21: 165,
#   22: 78,
#   23: 565,
#   24: 35,
#   25: 77,
#   26: 65,
#   27: 851,
#   28: 79,
#   29: 89,
#   30: 228,
#   31: 55,
#   32: 34,
#   33: 31,
#   34: 111,
#   35: 22,
#   36: 17,
#   37: 72,
#   38: 36,
#   39: 57,
#   40: 11,
#   41: 87,
#   42: 42,
#   43: 9,
#   44: 104,
#   45: 116,
#   46: 119,
#   47: 97,
#   48: 90,
#   49: 16,
#   50: 4,
#   51: 5,
#   52: 143,
#   53: 174,
#   54: 37,
#   55: 58,
#   56: 34,
#   57: 107,
#   58: 179,
#   59: 67,
#   60: 9,
#   61: 118,
#   62: 247,
#   63: 43,
#   64: 28,
#   65: 5,
#   66: 62,
#   67: 61,
#   68: 8,
#   69: 29,
#   70: 27,
#   71: 7,
#   72: 10,
#   73: 17,
#   74: 114,
#   75: 66,
#   76: 6,
#   77: 40,
#   78: 46,
#   79: 42,
#   80: 31,
#   81: 18,
#   82: 5,
# ...
